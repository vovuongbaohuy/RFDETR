# %%
# !pip uninstall pinecone
# Out:
# ^C

# %%
import os
from pinecone import Pinecone, ServerlessSpec

os.environ["PINECONE_API_KEY"] = "pcsk_2wq29h_4Ay9y6gqyo5ngS2ohu61ohVvSBK6tgY9NW5Gfja5Z5iuXmo66MPZ8x5qZYSMFBt"
os.environ["PINECONE_ENVIRONMENT"] = "us-east-1"  # e.g., "gcp-starter"


api_key =  "pcsk_43w88_LjfYiw31KiNpxvpo5GRa3hbP1XDN2Jif9hD494NZQdWWvSm9fxq95UCPLhFd4pf"
pc = Pinecone(api_key=api_key)  # OR use os.environ.get("PINECONE_API_KEY")


index_name = "dify-embedding"
index = pc.Index(index_name)

# %%
# Format for upsert: List of (id, vector, metadata)
vectors_to_upsert = [
    (item["id"], item["embedding"], item["metadata"])
    for item in embedded_data
]

# Now upsert
index.upsert(vectors=vectors_to_upsert)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 8
#       2 vectors_to_upsert = [
#       3     (item["id"], item["embedding"], item["metadata"])
#       4     for item in embedded_data
#       5 ]
#       7 # Now upsert
# ----> 8 index.upsert(vectors=vectors_to_upsert)
#
# NameError: name 'index' is not defined

# %%
embedded_data = [
        {
          "embedding": [
            -0.006959496,
            -0.03527426,
            0.0015957316,
            0.06534461,
            0.032938413,
            -0.024201158,
            -0.026108274,
            0.04937805,
            0.016232664,
            -0.05168433,
            -0.013357206,
            -0.014599049,
            -0.026019571,
            -0.0032579903,
            0.024585538,
            0.0011716199,
            -0.053458393,
            0.015057349,
            0.011487049,
            0.033943713,
            0.04934848,
            0.020372141,
            -0.013963344,
            0.018878974,
            0.017149262,
            0.024156807,
            0.018272836,
            -0.0011956437,
            0.01955903,
            -0.036782213,
            0.027675362,
            -0.028207581,
            0.027645795,
            -0.016232664,
            -0.011716199,
            -0.016040474,
            -0.014074223,
            0.03758054,
            0.018878974,
            -0.037698813,
            0.043434944,
            -0.01241104,
            0.020948712,
            0.013556788,
            0.0019680997,
            0.00021806174,
            -0.049171075,
            0.008323306,
            0.018331971,
            0.029464208,
            -0.026788332,
            0.007635857,
            0.02501427,
            0.10638457,
            0.036249995,
            -0.010289558,
            0.05954934,
            0.023609804,
            -0.0040766457,
            0.00014760748,
            -0.01905638,
            0.00968342,
            0.00833809,
            0.00409143,
            -0.0071221185,
            -0.013593747,
            -0.023905482,
            0.012167106,
            -0.020933928,
            -0.013837681,
            -0.0013979976,
            0.036220428,
            -0.02866588,
            -0.0071849497,
            -0.0043981946,
            -0.030188616,
            -0.085332364,
            -0.037757948,
            -0.001256627,
            0.009742555,
            -0.027424037,
            0.02217577,
            -0.037107456,
            -0.011937957,
            -0.056296892,
            -0.0060687694,
            -0.08083808,
            0.016350936,
            -0.026684845,
            -0.009269472,
            -0.015700446,
            0.044203702,
            -0.028414555,
            -0.023609804,
            0.009350783,
            0.011649672,
            -0.024733378,
            -0.00115776,
            0.059076253,
            -0.009380351,
            0.03787622,
            -0.029375505,
            0.039679848,
            -0.010548275,
            0.011538793,
            0.039265897,
            0.008456361,
            -0.011228332,
            -0.05313315,
            0.02559084,
            0.01260323,
            -0.034298524,
            -0.015803933,
            -0.00007484323,
            0.011812294,
            -0.0026019572,
            -0.012980218,
            -0.019071164,
            -0.006017026
          ],
          "id": "29a996a4-d198-4ca9-bee2-f1167d989dd8",
          "input_length": 2,
          "metadata": {
            "chunk_end_char": 2,
            "chunk_id": "chunk_001",
            "chunk_keywords": [
              "greeting",
              "salutation",
              "hello"
            ],
            "chunk_language": "en",
            "chunk_page_number": 1,
            "chunk_section": "",
            "chunk_source": "document",
            "chunk_start_char": 0,
            "chunk_title": "Greeting"
          },
          "model": "text-embedding-3-small",
          "text": "Hi"
        }
      ]

# %%
from pinecone import Pinecone

pc = Pinecone(api_key="********-****-****-****-************")
index = pc.Index("quickstart")

# %%
import json

# Corrected JSON string (escaped `query` properly terminated)
escaped_json_str = r'''
{
  "query": "Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.",
  "files": [],
  "json": [
    {
      "chunks": [
        {
          "chunk_id": "chunk_001",
          "chunk_title": "Overview of Sydney Sweeney's Career and Achievements",
          "chunk_text": "Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.",
          "chunk_keywords": [
            "Sydney Sweeney",
            "actress",
            "producer",
            "Euphoria",
            "The White Lotus",
            "Hollywood",
            "acting career",
            "critical acclaim",
            "upcoming projects"
          ],
          "chunk_start_char": 0,
          "chunk_end_char": 684,
          "chunk_section": "Introduction",
          "chunk_page_number": 1,
          "chunk_language": "en",
          "chunk_source": "Document provided"
        }
      ],
      "query": "{\"chunks\": [{\"chunk_id\": \"chunk_001\", \"chunk_title\": \"Overview of Sydney Sweeney's Career and Achievements\", \"chunk_text\": \"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\", \"chunk_keywords\": [\"Sydney Sweeney\", \"actress\", \"producer\", \"Euphoria\", \"The White Lotus\", \"Hollywood\", \"acting career\", \"critical acclaim\", \"upcoming projects\"], \"chunk_start_char\": 0, \"chunk_end_char\": 684, \"chunk_section\": \"Introduction\", \"chunk_page_number\": 1, \"chunk_language\": \"en\", \"chunk_source\": \"Document provided\"}]}"
    }
  ]
}
'''

# Parse JSON
parsed_json = json.loads(escaped_json_str)

# # Print top-level query
# print(parsed_json["query"])

# Optional: parse the nested query string inside `json[0]["query"]`
nested_query = json.loads(parsed_json["json"][0]["query"])

# Print nested content
print(json.dumps(nested_query, indent=2))

# Save to file
# with open("output.json", "w", encoding="utf-8") as f:
#     json.dump(parsed_json, f, indent=2, ensure_ascii=False)

# %%
import json

# Your string (wrapped JSON)
wrapped_json_string = '''"{\\n  \\"query\\": \\"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\\",\\n  \\"files\\": [],\\n  \\"json\\": [\\n    {\\n      \\"chunks\\": [\\n        {\\n          \\"chunk_id\\": \\"chunk_001\\",\\n          \\"chunk_title\\": \\"Overview of Sydney Sweeney's Career and Achievements\\",\\n          \\"chunk_text\\": \\"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\\",\\n          \\"chunk_keywords\\": [\\n            \\"Sydney Sweeney\\",\\n            \\"actress\\",\\n            \\"producer\\",\\n            \\"Euphoria\\",\\n            \\"The White Lotus\\",\\n            \\"Hollywood\\",\\n            \\"acting career\\",\\n            \\"critical acclaim\\",\\n            \\"upcoming projects\\"\\n          ],\\n          \\"chunk_start_char\\": 0,\\n          \\"chunk_end_char\\": 684,\\n          \\"chunk_section\\": \\"Introduction\\",\\n          \\"chunk_page_number\\": 1,\\n          \\"chunk_language\\": \\"en\\",\\n          \\"chunk_source\\": \\"Document provided\\"\\n        }\\n      ],\\n      \\"query\\": \\"{\\\\\\"chunks\\\\\\": [{\\\\\\"chunk_id\\\\\\": \\\\\\"chunk_001\\\\\\", \\\\\\"chunk_title\\\\\\": \\\\\\"Overview of Sydney Sweeney's Career and Achievements\\\\\\", \\\\\\"chunk_text\\\\\\": \\\\\\"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\\\\\\", \\\\\\"chunk_keywords\\\\\\": [\\\\\\"Sydney Sweeney\\\\\\", \\\\\\"actress\\\\\\", \\\\\\"producer\\\\\\", \\\\\\"Euphoria\\\\\\", \\\\\\"The White Lotus\\\\\\", \\\\\\"Hollywood\\\\\\", \\\\\\"acting career\\\\\\", \\\\\\"critical acclaim\\\\\\", \\\\\\"upcoming projects\\\\\\"], \\\\\\"chunk_start_char\\\\\\": 0, \\\\\\"chunk_end_char\\\\\\": 684, \\\\\\"chunk_section\\\\\\": \\\\\\"Introduction\\\\\\", \\\\\\"chunk_page_number\\\\\\": 1, \\\\\\"chunk_language\\\\\\": \\\\\\"en\\\\\\", \\\\\\"chunk_source\\\\\\": \\\\\\"Document provided\\\\\\"}]}\"\\n    }\\n  ]\\n}"'''

# Step 1: Strip the wrapping quotes if they exist
if wrapped_json_string.startswith('"') and wrapped_json_string.endswith('"'):
    wrapped_json_string = wrapped_json_string[1:-1]

# Step 2: Decode escape characters
unescaped_string = bytes(wrapped_json_string, "utf-8").decode("unicode_escape")

# Step 3: Parse JSON
parsed_json = json.loads(unescaped_string)

# Optional: Pretty print
print(json.dumps(parsed_json, indent=2, ensure_ascii=False))

# %%
import json

# Your original JSON with inner JSON string in the "query" field
outer_json = {
  "query": "{\n  \"query\": \"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\",\n  \"files\": [],\n  \"json\": [\n    {\n      \"chunks\": [\n        {\n          \"chunk_id\": \"chunk_001\",\n          \"chunk_title\": \"Overview of Sydney Sweeney's Career and Achievements\",\n          \"chunk_text\": \"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\",\n          \"chunk_keywords\": [\n            \"Sydney Sweeney\",\n            \"actress\",\n            \"producer\",\n            \"Euphoria\",\n            \"The White Lotus\",\n            \"Hollywood\",\n            \"acting career\",\n            \"critical acclaim\",\n            \"upcoming projects\"\n          ],\n          \"chunk_start_char\": 0,\n          \"chunk_end_char\": 684,\n          \"chunk_section\": \"Introduction\",\n          \"chunk_page_number\": 1,\n          \"chunk_language\": \"en\",\n          \"chunk_source\": \"Document provided\"\n        }\n      ],\n      \"query\": \"{\\\"chunks\\\": [{\\\"chunk_id\\\": \\\"chunk_001\\\", \\\"chunk_title\\\": \\\"Overview of Sydney Sweeney's Career and Achievements\\\", \\\"chunk_text\\\": \\\"Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.\\\", \\\"chunk_keywords\\\": [\\\"Sydney Sweeney\\\", \\\"actress\\\", \\\"producer\\\", \\\"Euphoria\\\", \\\"The White Lotus\\\", \\\"Hollywood\\\", \\\"acting career\\\", \\\"critical acclaim\\\", \\\"upcoming projects\\\"], \\\"chunk_start_char\\\": 0, \\\"chunk_end_char\\\": 684, \\\"chunk_section\\\": \\\"Introduction\\\", \\\"chunk_page_number\\\": 1, \\\"chunk_language\\\": \\\"en\\\", \\\"chunk_source\\\": \\\"Document provided\\\"}]}\"\n    }\n  ]\n}"
}

# Step 1: Extract the inner string from the "query" key
inner_json_str = outer_json["query"]
print(f"Inner JSON string: {inner_json_str}")
# Step 2: Convert that inner string into a Python dictionary
inner_data = json.loads(inner_json_str)

# Step 3: Optional: Pretty print the parsed inner JSON
print(json.dumps(inner_data, indent=2, ensure_ascii=False))
# Out:
# Inner JSON string: {
#   "query": "Sydney Sweeney is an American actress and producer best known for her standout roles in popular television series and films. Rising to fame with her performances in Euphoria as Cassie Howard and The White Lotus as Olivia Mossbacher, she has garnered critical acclaim for her compelling portrayals of complex characters. Beyond acting, Sweeney has ventured into producing, further establishing herself as a multifaceted talent in Hollywood. With her striking screen presence and dedication to her craft, she continues to be one of the most talked-about young stars in the entertainment industry. Her upcoming projects and dynamic range ensure that her career remains on an exciting upward trajectory.",
#   "files": [],
#   "json": [
#     {
#       "chunks": [
#         {
#           "chunk_id": "chunk_001",
#           "chunk_title": "Overview of Sydney Sweeney's Career and Achievements",
# ...

# %% [markdown]
# ## Mapping New Id For New Class

# %% [markdown]
# | New Class ID | New Class Name | Old Class IDs Grouped |
# | ------------ | -------------- | --------------------- |
# | 0            | three\_wheels  | 2, 6, 13              |
# | 1            | bus            | 4, 7, 10              |
# | 2            | car            | 0, 5, 12, 9           |
# | 3            | tractor        | 14                    |
# | 4            | truck          | 8, 16, 15             |
# | 5            | ambulance      | 1                     |
# | 6            | van            | 17                    |
# | 7            | motorbikes     | 3, 11                 |

# %% [markdown]
# ## Reduce the classes of the dataset

# %%
from pathlib import Path

# Original dataset with nested /labels folders
dataset_dir = Path(r"D:\new\slm-ragas\visualize\data\Nepali_vehicle_dataset")
output_dir = Path(r"D:\new\slm-ragas\visualize\data\Nepali_vehicle_dataset_reduced")
output_dir.mkdir(parents=True, exist_ok=True)

# Class ID remap
remap = {
    2: 0, 6: 0, 13: 0,        # three_wheels
    4: 1, 7: 1, 10: 1,        # bus
    0: 2, 5: 2, 12: 2, 9: 2,  # car
    14: 3,                   # tractor
    8: 4, 16: 4, 15: 4,       # truck
    1: 5,                    # ambulance
    17: 6,                   # van
    3: 7, 11: 7              # motorbikes
}

# Debugging info
print("Starting class remapping...")

# Traverse all folders like SUV/labels, bus/labels, etc.
for class_folder in dataset_dir.iterdir():
    if not class_folder.is_dir():
        continue
    
    label_dir = class_folder / "labels"
    if not label_dir.exists():
        continue
    
    for label_file in label_dir.glob("*.txt"):
        with open(label_file, "r") as f:
            lines = f.readlines()

        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if not parts:
                continue
            try:
                old_class_id = int(parts[0])
                if old_class_id not in remap:
                    print(f"Skipping unknown ID {old_class_id} in {label_file}")
                    continue
                new_class_id = remap[old_class_id]
                parts[0] = str(new_class_id)
                new_lines.append(" ".join(parts))
            except ValueError:
                print(f"Invalid line in {label_file}: {line}")

        # Only write if there's valid data
        if new_lines:
            relative_path = label_file.relative_to(dataset_dir)
            new_label_path = output_dir / relative_path
            new_label_path.parent.mkdir(parents=True, exist_ok=True)
            with open(new_label_path, "w") as f:
                f.write("\n".join(new_lines))
            print(f"Written: {new_label_path}")

print("Remapping complete.")

# %% [markdown]
# ## Copy all the files from one folder to another Function

# %%
import shutil
from pathlib import Path

def copy_files(src_folder: Path, dst_folder: Path):
    # Source and destination folders
    src_folder = src_folder
    dst_folder = dst_folder

    # Create destination folder if it doesn't exist
    dst_folder.mkdir(parents=True, exist_ok=True)

    # Copy all files from src to dst
    for file in src_folder.glob("*.*"):  # or "*.jpg", "*.txt", etc.
        if file.is_file():
            shutil.copy(file, dst_folder / file.name)
    print(f"Copied files from {src_folder} to {dst_folder} successfully.")

# %% [markdown]
# ## Copy Missing Image

# %%
# 1. Ambulance
copy_files(Path(r"data\Nepali_vehicle_dataset\ambulance\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\ambulance\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\ambulance\images to data\Nepali_vehicle_dataset_reduced\ambulance\images successfully.

# %%
# 2. Auto Rickshaw
copy_files(Path(r"data\Nepali_vehicle_dataset\auto_rickshaw\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\auto_rickshaw\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\auto_rickshaw\images to data\Nepali_vehicle_dataset_reduced\auto_rickshaw\images successfully.

# %%
# 3. Bikes
copy_files(Path(r"data\Nepali_vehicle_dataset\bikes\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\bikes\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\bikes\images to data\Nepali_vehicle_dataset_reduced\bikes\images successfully.

# %%
# 4. Bus
copy_files(Path(r"data\Nepali_vehicle_dataset\bus\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\bus\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\bus\images to data\Nepali_vehicle_dataset_reduced\bus\images successfully.

# %%
# 5. Car
copy_files(Path(r"data\Nepali_vehicle_dataset\car\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\car\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\car\images to data\Nepali_vehicle_dataset_reduced\car\images successfully.

# %%
# 6. E Rickshaw
copy_files(Path(r"data\Nepali_vehicle_dataset\e-rickshaw\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\e-rickshaw\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\e-rickshaw\images to data\Nepali_vehicle_dataset_reduced\e-rickshaw\images successfully.

# %%
# 7. Microbus
copy_files(Path(r"data\Nepali_vehicle_dataset\micro_bus\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\micro_bus\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\micro_bus\images to data\Nepali_vehicle_dataset_reduced\micro_bus\images successfully.

# %%
# 8. Mini Truck
copy_files(Path(r"data\Nepali_vehicle_dataset\mini_truck\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\mini_truck\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\mini_truck\images to data\Nepali_vehicle_dataset_reduced\mini_truck\images successfully.

# %%
# 9. Police Vehicle
copy_files(Path(r"data\Nepali_vehicle_dataset\police_vehicle\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\police_vehicle\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\police_vehicle\images to data\Nepali_vehicle_dataset_reduced\police_vehicle\images successfully.

# %%
# 10. School Bus
copy_files(Path(r"data\Nepali_vehicle_dataset\school_bus\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\school_bus\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\school_bus\images to data\Nepali_vehicle_dataset_reduced\school_bus\images successfully.

# %%
# 11. Scooter
copy_files(Path(r"data\Nepali_vehicle_dataset\scooter\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\scooter\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\scooter\images to data\Nepali_vehicle_dataset_reduced\scooter\images successfully.

# %%
# 12. SUV
copy_files(Path(r"data\Nepali_vehicle_dataset\SUV\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\SUV\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\SUV\images to data\Nepali_vehicle_dataset_reduced\SUV\images successfully.

# %%
# 13. Taxi
copy_files(Path(r"data\Nepali_vehicle_dataset\taxi\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\taxi\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\taxi\images to data\Nepali_vehicle_dataset_reduced\taxi\images successfully.

# %%
# 14. Tempo
copy_files(Path(r"data\Nepali_vehicle_dataset\tempo\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\tempo\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\tempo\images to data\Nepali_vehicle_dataset_reduced\tempo\images successfully.

# %%
# 15. Tractor
copy_files(Path(r"data\Nepali_vehicle_dataset\tractor\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\tractor\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\tractor\images to data\Nepali_vehicle_dataset_reduced\tractor\images successfully.

# %%
# 16. Transport Vehicle
copy_files(Path(r"data\Nepali_vehicle_dataset\transport_vehicle\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\transport_vehicle\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\transport_vehicle\images to data\Nepali_vehicle_dataset_reduced\transport_vehicle\images successfully.

# %%
# 17. Transport Vehicle
copy_files(Path(r"data\Nepali_vehicle_dataset\truck\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\truck\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\truck\images to data\Nepali_vehicle_dataset_reduced\truck\images successfully.

# %%
# 18. Van
copy_files(Path(r"data\Nepali_vehicle_dataset\van\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\van\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\van\images to data\Nepali_vehicle_dataset_reduced\van\images successfully.

# %% [markdown]
# ## Convert Data Format From Yolo To CoCo function

# %%
import os
import json
from PIL import Image

def convert_yolo_to_coco(dataset_path):
    # Update your dataset path here
    dataset_path = dataset_path
    images_dir = os.path.join(dataset_path, "images")
    labels_dir = os.path.join(dataset_path, "labels")

    # Create output dictionary in COCO format
    coco_output = {
        "images": [],
        "annotations": [],
        "categories": []
    }

    # Define categories (update with your actual class names if needed)
    category_names = ["ambulance"]  # replace/add as needed
    category_map = {name: i+1 for i, name in enumerate(category_names)}  # COCO ids start at 1

    for cat_name, cat_id in category_map.items():
        coco_output["categories"].append({
            "id": cat_id,
            "name": cat_name,
            "supercategory": "vehicle"
        })

    annotation_id = 1
    image_id = 1

    for image_filename in os.listdir(images_dir):
        if not image_filename.lower().endswith((".jpg", ".png", ".jpeg")):
            continue

        image_path = os.path.join(images_dir, image_filename)
        label_path = os.path.join(labels_dir, os.path.splitext(image_filename)[0] + ".txt")

        # Skip if label doesn't exist
        if not os.path.exists(label_path):
            continue

        with Image.open(image_path) as img:
            width, height = img.size

        # Add image info
        coco_output["images"].append({
            "id": image_id,
            "file_name": image_filename,
            "width": width,
            "height": height
        })

        # Read YOLO labels
        with open(label_path, "r") as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) != 5:
                    continue
                class_id, x_center, y_center, bbox_width, bbox_height = map(float, parts)
                class_id = int(class_id)

                # Convert to COCO bbox format: [x_min, y_min, width, height]
                x = (x_center - bbox_width / 2) * width
                y = (y_center - bbox_height / 2) * height
                w = bbox_width * width
                h = bbox_height * height

                coco_output["annotations"].append({
                    "id": annotation_id,
                    "image_id": image_id,
                    "category_id": class_id + 1,  # because COCO ids start at 1
                    "bbox": [x, y, w, h],
                    "area": w * h,
                    "iscrowd": 0
                })
                annotation_id += 1

        image_id += 1

    # Save to COCO JSON
    output_json_path = os.path.join(dataset_path, "_annotations.coco.json")
    with open(output_json_path, "w") as f:
        json.dump(coco_output, f, indent=4)

    print("YOLO to COCO conversion complete!")

# %% [markdown]
# ## Process Ambulance Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\ambulance")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ##  Process Auto Rickshaw Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\auto_rickshaw")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Bikes Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\bikes")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Bus Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\bus")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Car Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\car")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process E-Rickshaw Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\e-rickshaw")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Mirco-bus Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\micro_bus")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Mini Truck Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\mini_truck")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Police Vehicle Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\police_vehicle")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process School Bus Vehicle Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\school_bus")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Scooter Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\scooter")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process SUV Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\SUV")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Taxi Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\taxi")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Tempo Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\tempo")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Tractor Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\tractor")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Transport Vehicle Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\transport_vehicle")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Truck Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\truck")
# Out:
# YOLO to COCO conversion complete!

# %% [markdown]
# ## Process Van Data

# %%
convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\van")
# Out:
# YOLO to COCO conversion complete!
