# %% [markdown]
# ## Mapping New Id For New Class

# %% [markdown]
# | New Class ID | New Class Name | Old Class IDs Grouped |
# | ------------ | -------------- | --------------------- |
# | 0            | three\_wheels  | 2, 6, 13              |
# | 1            | bus            | 4, 7, 10              |
# | 2            | car            | 0, 5, 12, 9           |
# | 3            | tractor        | 14                    |
# | 4            | truck          | 8, 16, 15             |
# | 5            | ambulance      | 1                     |
# | 6            | van            | 17                    |
# | 7            | motorbikes     | 3, 11                 |

# %% [markdown]
# ## Reduce the classes of the dataset

# %%
from pathlib import Path

# Original dataset with nested /labels folders
dataset_dir = Path(r"data\Nepali_vehicle_dataset")
output_dir = Path(r"data\Nepali_vehicle_dataset_reduced")
output_dir.mkdir(parents=True, exist_ok=True)

# Class ID remap
remap = {
    2: 0, 6: 0, 13: 0,        # three_wheels
    4: 1, 7: 1, 10: 1,        # bus
    0: 2, 5: 2, 12: 2, 9: 2,  # car
    14: 3,                   # tractor
    8: 4, 16: 4, 15: 4,       # truck
    1: 5,                    # ambulance
    17: 6,                   # van
    3: 7, 11: 7              # motorbikes
}

# Debugging info
print("Starting class remapping...")

# Traverse all folders like SUV/labels, bus/labels, etc.
for class_folder in dataset_dir.iterdir():
    if not class_folder.is_dir():
        continue
    
    label_dir = class_folder / "labels"
    if not label_dir.exists():
        continue
    
    for label_file in label_dir.glob("*.txt"):
        with open(label_file, "r") as f:
            lines = f.readlines()

        new_lines = []
        for line in lines:
            parts = line.strip().split()
            if not parts:
                continue
            try:
                old_class_id = int(parts[0])
                if old_class_id not in remap:
                    print(f"Skipping unknown ID {old_class_id} in {label_file}")
                    continue
                new_class_id = remap[old_class_id]
                parts[0] = str(new_class_id)
                new_lines.append(" ".join(parts))
            except ValueError:
                print(f"Invalid line in {label_file}: {line}")

        # Only write if there's valid data
        if new_lines:
            relative_path = label_file.relative_to(dataset_dir)
            new_label_path = output_dir / relative_path
            new_label_path.parent.mkdir(parents=True, exist_ok=True)
            with open(new_label_path, "w") as f:
                f.write("\n".join(new_lines))
            print(f"Written: {new_label_path}")

print("Remapping complete.")
# Out:
# Starting class remapping...
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_1.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_10.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_100.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_101.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_102.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_103.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_104.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_105.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_106.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_107.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_108.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_109.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_11.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_110.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_111.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_113.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_114.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_115.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_116.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_117.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_118.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_119.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_12.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_120.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_121.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_122.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_123.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_124.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_125.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_126.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_127.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_128.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_129.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_13.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_130.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_131.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_132.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_133.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_134.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_135.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_136.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_138.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_139.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_14.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_140.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_141.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_142.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_143.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_144.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_145.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_146.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_147.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_148.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_149.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_15.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_150.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_151.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_152.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_153.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_154.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_155.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_156.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_157.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_158.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_159.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_16.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_160.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_161.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_162.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_163.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_164.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_165.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_166.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_167.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_168.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_169.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_17.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_170.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_171.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_172.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_173.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_174.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_175.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_176.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_177.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_178.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_179.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_18.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_180.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_182.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_183.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_184.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_185.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_186.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_187.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_188.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_189.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_19.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_190.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_191.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_192.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_193.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_194.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_195.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_196.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_197.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_198.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_199.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_2.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_20.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_200.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_201.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_202.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_203.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_204.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_205.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_206.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_207.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_208.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_209.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_21.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_210.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_211.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_212.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_213.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_214.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_215.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_216.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_217.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_218.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_219.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_22.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_220.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_221.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_222.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_223.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_224.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_225.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_226.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_227.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_228.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_229.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_23.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_230.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_231.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_232.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_233.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_234.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_235.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_236.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_237.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_238.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_239.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_24.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_240.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_241.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_242.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_243.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_244.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_245.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_246.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_247.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_248.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_249.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_25.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_250.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_251.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_252.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_253.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_254.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_255.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_256.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_257.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_258.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_259.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_26.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_261.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_262.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_263.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_264.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_265.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_266.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_267.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_268.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_269.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_27.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_270.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_271.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_272.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_273.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_274.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_275.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_276.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_277.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_278.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_279.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_28.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_280.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_281.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_282.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_283.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_284.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_285.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_286.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_287.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_288.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_289.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_29.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_290.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_291.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_292.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_293.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_294.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_295.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_296.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_297.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_298.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_299.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_3.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_30.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_300.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_301.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_302.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_303.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_304.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_305.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_306.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_307.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_308.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_31.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_32.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_33.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_34.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_35.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_36.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_37.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_38.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_39.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_4.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_40.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_41.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_42.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_43.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_44.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_45.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_46.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_47.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_48.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_49.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_5.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_50.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_51.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_52.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_54.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_55.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_56.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_57.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_58.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_59.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_6.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_60.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_61.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_62.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_63.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_64.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_65.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_66.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_67.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_68.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_69.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_7.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_70.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_71.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_72.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_73.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_74.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_75.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_76.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_77.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_78.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_79.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_8.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_80.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_81.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_82.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_83.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_84.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_85.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_86.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_87.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_88.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_89.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_9.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_90.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_91.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_92.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_93.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_94.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_95.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_96.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_97.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_98.txt
# Written: data\Nepali_vehicle_dataset_reduced\ambulance\labels\ambulance_99.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_1.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_10.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_100.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_101.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_102.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_103.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_104.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_105.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_106.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_107.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_108.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_109.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_11.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_110.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_111.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_112.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_113.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_114.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_115.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_116.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_117.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_118.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_119.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_12.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_120.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_121.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_122.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_123.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_124.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_125.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_126.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_127.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_128.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_129.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_13.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_130.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_131.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_132.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_133.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_134.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_135.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_136.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_137.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_138.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_139.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_14.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_140.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_141.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_142.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_143.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_144.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_145.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_146.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_147.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_148.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_149.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_15.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_150.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_151.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_152.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_153.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_154.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_155.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_156.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_157.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_158.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_159.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_16.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_160.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_161.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_162.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_163.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_164.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_165.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_166.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_167.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_168.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_169.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_17.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_170.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_171.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_172.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_173.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_174.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_175.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_176.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_177.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_178.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_179.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_18.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_180.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_181.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_182.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_183.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_184.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_185.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_186.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_187.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_188.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_189.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_19.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_190.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_191.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_192.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_193.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_194.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_195.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_196.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_197.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_198.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_199.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_2.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_20.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_200.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_201.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_202.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_203.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_204.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_205.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_206.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_207.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_208.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_209.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_21.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_210.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_211.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_212.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_213.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_214.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_215.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_216.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_217.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_218.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_219.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_22.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_220.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_221.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_222.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_223.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_224.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_225.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_226.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_227.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_228.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_229.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_23.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_230.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_231.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_232.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_233.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_234.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_235.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_237.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_238.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_239.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_24.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_240.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_241.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_242.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_243.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_244.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_245.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_246.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_247.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_248.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_249.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_25.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_250.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_251.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_252.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_253.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_254.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_255.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_256.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_257.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_258.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_259.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_26.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_260.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_261.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_262.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_263.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_264.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_265.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_266.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_267.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_268.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_269.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_27.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_270.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_271.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_272.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_273.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_274.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_275.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_276.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_277.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_278.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_279.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_28.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_280.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_281.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_282.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_283.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_284.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_285.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_286.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_287.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_288.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_289.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_29.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_290.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_291.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_293.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_294.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_295.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_296.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_297.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_298.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_299.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_3.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_30.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_300.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_31.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_32.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_33.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_34.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_35.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_36.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_37.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_38.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_39.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_4.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_40.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_41.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_42.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_43.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_44.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_45.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_46.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_47.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_48.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_49.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_5.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_50.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_51.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_52.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_53.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_54.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_55.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_56.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_57.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_58.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_59.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_6.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_60.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_61.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_62.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_63.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_64.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_65.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_66.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_67.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_68.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_69.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_7.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_70.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_71.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_72.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_73.txt
# Written: data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels\auto_rickshaw_74.txt
# ...
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_157.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_158.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_159.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_16.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_160.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_161.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_162.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_163.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_164.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_165.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_166.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_167.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_168.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_169.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_17.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_170.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_171.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_172.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_173.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_174.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_175.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_176.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_177.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_178.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_179.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_18.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_180.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_181.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_182.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_183.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_184.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_185.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_186.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_187.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_188.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_189.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_19.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_190.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_191.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_192.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_193.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_194.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_195.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_196.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_197.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_198.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_199.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_2.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_20.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_200.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_201.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_202.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_203.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_204.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_205.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_206.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_207.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_208.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_209.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_21.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_210.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_211.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_212.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_213.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_214.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_215.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_216.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_217.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_218.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_219.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_22.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_220.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_221.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_222.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_223.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_224.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_225.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_226.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_227.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_228.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_229.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_23.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_230.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_231.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_232.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_233.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_234.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_235.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_236.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_237.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_238.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_239.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_24.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_240.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_241.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_242.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_243.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_244.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_245.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_246.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_247.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_248.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_249.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_25.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_250.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_251.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_252.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_253.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_254.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_255.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_256.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_257.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_258.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_259.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_26.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_260.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_261.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_262.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_263.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_264.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_265.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_266.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_267.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_268.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_269.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_27.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_270.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_271.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_272.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_273.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_274.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_275.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_276.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_277.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_278.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_279.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_28.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_280.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_281.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_282.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_283.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_284.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_285.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_286.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_287.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_288.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_289.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_29.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_290.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_291.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_292.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_293.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_294.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_295.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_296.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_297.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_298.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_299.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_3.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_30.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_300.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_31.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_32.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_33.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_34.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_35.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_36.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_37.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_38.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_39.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_4.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_40.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_41.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_42.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_43.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_44.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_45.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_46.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_47.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_48.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_49.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_5.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_50.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_51.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_52.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_53.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_54.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_55.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_56.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_57.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_58.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_59.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_6.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_60.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_61.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_62.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_63.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_64.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_65.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_66.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_67.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_68.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_69.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_7.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_70.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_71.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_72.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_73.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_74.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_75.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_76.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_77.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_78.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_79.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_8.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_80.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_81.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_82.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_83.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_84.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_85.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_86.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_87.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_88.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_89.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_9.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_90.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_91.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_92.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_93.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_94.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_95.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_96.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_97.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_98.txt
# Written: data\Nepali_vehicle_dataset_reduced\van\labels\van_99.txt
# Remapping complete.

# %% [markdown]
# ## Copy all the files from one folder to another Function

# %%
import shutil
from pathlib import Path

def copy_files(src_folder: Path, dst_folder: Path):
    # Source and destination folders
    src_folder = src_folder
    dst_folder = dst_folder

    # Create destination folder if it doesn't exist
    dst_folder.mkdir(parents=True, exist_ok=True)

    # Copy all files from src to dst
    for file in src_folder.glob("*.*"):  # or "*.jpg", "*.txt", etc.
        if file.is_file():
            shutil.copy(file, dst_folder / file.name)
    print(f"Copied files from {src_folder} to {dst_folder} successfully.")

# %% [markdown]
# ## Copy Missing Image

# %%
# 1. Ambulance
copy_files(Path(r"data\Nepali_vehicle_dataset\ambulance\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\ambulance\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\ambulance\images to data\Nepali_vehicle_dataset_reduced\ambulance\images successfully.

# %%
# 2. Auto Rickshaw
copy_files(Path(r"data\Nepali_vehicle_dataset\auto_rickshaw\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\auto_rickshaw\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\auto_rickshaw\images to data\Nepali_vehicle_dataset_reduced\auto_rickshaw\images successfully.

# %%
# 3. Bikes
copy_files(Path(r"data\Nepali_vehicle_dataset\bikes\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\bikes\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\bikes\images to data\Nepali_vehicle_dataset_reduced\bikes\images successfully.

# %%
# 4. Bus
copy_files(Path(r"data\Nepali_vehicle_dataset\bus\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\bus\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\bus\images to data\Nepali_vehicle_dataset_reduced\bus\images successfully.

# %%
# 5. Car
copy_files(Path(r"data\Nepali_vehicle_dataset\car\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\car\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\car\images to data\Nepali_vehicle_dataset_reduced\car\images successfully.

# %%
# 6. E Rickshaw
copy_files(Path(r"data\Nepali_vehicle_dataset\e-rickshaw\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\e-rickshaw\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\e-rickshaw\images to data\Nepali_vehicle_dataset_reduced\e-rickshaw\images successfully.

# %%
# 7. Microbus
copy_files(Path(r"data\Nepali_vehicle_dataset\micro_bus\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\micro_bus\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\micro_bus\images to data\Nepali_vehicle_dataset_reduced\micro_bus\images successfully.

# %%
# 8. Mini Truck
copy_files(Path(r"data\Nepali_vehicle_dataset\mini_truck\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\mini_truck\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\mini_truck\images to data\Nepali_vehicle_dataset_reduced\mini_truck\images successfully.

# %%
# 9. Police Vehicle
copy_files(Path(r"data\Nepali_vehicle_dataset\police_vehicle\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\police_vehicle\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\police_vehicle\images to data\Nepali_vehicle_dataset_reduced\police_vehicle\images successfully.

# %%
# 10. School Bus
copy_files(Path(r"data\Nepali_vehicle_dataset\school_bus\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\school_bus\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\school_bus\images to data\Nepali_vehicle_dataset_reduced\school_bus\images successfully.

# %%
# 11. Scooter
copy_files(Path(r"data\Nepali_vehicle_dataset\scooter\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\scooter\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\scooter\images to data\Nepali_vehicle_dataset_reduced\scooter\images successfully.

# %%
# 12. SUV
copy_files(Path(r"data\Nepali_vehicle_dataset\SUV\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\SUV\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\SUV\images to data\Nepali_vehicle_dataset_reduced\SUV\images successfully.

# %%
# 13. Taxi
copy_files(Path(r"data\Nepali_vehicle_dataset\taxi\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\taxi\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\taxi\images to data\Nepali_vehicle_dataset_reduced\taxi\images successfully.

# %%
# 14. Tempo
copy_files(Path(r"data\Nepali_vehicle_dataset\tempo\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\tempo\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\tempo\images to data\Nepali_vehicle_dataset_reduced\tempo\images successfully.

# %%
# 15. Tractor
copy_files(Path(r"data\Nepali_vehicle_dataset\tractor\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\tractor\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\tractor\images to data\Nepali_vehicle_dataset_reduced\tractor\images successfully.

# %%
# 16. Transport Vehicle
copy_files(Path(r"data\Nepali_vehicle_dataset\transport_vehicle\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\transport_vehicle\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\transport_vehicle\images to data\Nepali_vehicle_dataset_reduced\transport_vehicle\images successfully.

# %%
# 17. Truck
copy_files(Path(r"data\Nepali_vehicle_dataset\truck\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\truck\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\truck\images to data\Nepali_vehicle_dataset_reduced\truck\images successfully.

# %%
# 18. Van
copy_files(Path(r"data\Nepali_vehicle_dataset\van\images"),
           Path(r"data\Nepali_vehicle_dataset_reduced\van\images"))
# Out:
# Copied files from data\Nepali_vehicle_dataset\van\images to data\Nepali_vehicle_dataset_reduced\van\images successfully.

# %% [markdown]
# ## Convert Data Label Format From Yolo To CoCo function

# %%
import os
import json
from PIL import Image

def convert_yolo_to_coco(dataset_path, category_names):
    """
    Convert YOLO-format annotations (txt) into COCO-format JSON.
    Expects YOLO labels already remapped to 0..N-1.
    """
    images_dir = os.path.join(dataset_path, "images")
    labels_dir = os.path.join(dataset_path, "labels")

    coco_output = {
        "info": {
            "description": "Nepali Vehicle Dataset",
            "version": "1.0",
            "year": 2025,
            "contributor": "Custom Conversion",
            "date_created": "2025-08-19"
        },
        "licenses": [
            {
                "id": 1,
                "name": "Unknown",
                "url": "http://example.com"
            }
        ],
        "images": [],
        "annotations": [],
        "categories": []
    }

    # Build categories from given names (0-based)
    for i, name in enumerate(category_names):
        coco_output["categories"].append({
            "id": i,
            "name": name,
            "supercategory": "vehicle"
        })

    annotation_id = 1
    image_id = 1

    for image_filename in os.listdir(images_dir):
        if not image_filename.lower().endswith((".jpg", ".jpeg", ".png")):
            continue

        image_path = os.path.join(images_dir, image_filename)
        label_path = os.path.join(labels_dir, os.path.splitext(image_filename)[0] + ".txt")

        if not os.path.exists(label_path):
            continue

        with Image.open(image_path) as img:
            width, height = img.size

        # Add image entry
        coco_output["images"].append({
            "id": image_id,
            "file_name": image_filename,
            "width": width,
            "height": height
        })

        # Read YOLO label file
        with open(label_path, "r") as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) != 5:
                    continue
                class_id, x_center, y_center, bbox_width, bbox_height = map(float, parts)
                class_id = int(class_id)  # already 0–7 after your remap script

                # Convert YOLO -> COCO
                x = (x_center - bbox_width / 2) * width
                y = (y_center - bbox_height / 2) * height
                w = bbox_width * width
                h = bbox_height * height

                coco_output["annotations"].append({
                    "id": annotation_id,
                    "image_id": image_id,
                    "category_id": class_id,
                    "bbox": [x, y, w, h],
                    "area": w * h,
                    "iscrowd": 0
                })
                annotation_id += 1

        image_id += 1

    # Save
    output_json_path = os.path.join(dataset_path, "_annotations.coco.json")
    with open(output_json_path, "w") as f:
        json.dump(coco_output, f, indent=4)

    print(f"YOLO → COCO conversion complete! Saved to {output_json_path}")

# %% [markdown]
# ## Function to count how many classes are there in a YOLO dataset

# %%
import os
from collections import Counter

def count_yolo_classes(labels_dir):
    class_ids = []
    for root, _, files in os.walk(labels_dir):
        for file in files:
            if file.endswith(".txt"):
                path = os.path.join(root, file)
                with open(path, "r") as f:
                    for line in f:
                        if line.strip():
                            try:
                                class_id = int(line.split()[0])
                                class_ids.append(class_id)
                            except ValueError:
                                print(f"⚠️ Skipping malformed line in {path}: {line.strip()}")
    
    counter = Counter(class_ids)
    return counter

# %% [markdown]
# ## Split CoCo Data Set into Train, Valid, Test (70/20/10)

# %%
from pycocotools.coco import COCO
import json, os, shutil
import numpy as np

def split_coco_dataset(dataset_dir, ann_filename="_annotations.coco.json", 
                       splits=(0.7, 0.2, 0.1), 
                       output_dirs=("train", "valid", "test")):
    """
    Split a COCO dataset into train/val/test subsets and save images + annotation files.
    
    Args:
        dataset_dir (str): Root folder containing 'images' and the annotation JSON file.
        ann_filename (str): Name of the annotation JSON file (default "_annotations.coco.json").
        splits (tuple): Fractions for train, val, test (should sum <= 1.0).
        output_dirs (tuple): Names of subfolders for train/val/test splits.
    """
    ann_file = os.path.join(dataset_dir, f"images/{ann_filename}")

    # Load original annotation file
    with open(ann_file, "r") as f:
        ann_data = json.load(f)

    # COCO helper
    coco = COCO(ann_file)
    image_ids = coco.getImgIds()
    np.random.shuffle(image_ids)

    n_total = len(image_ids)
    n_train = int(splits[0] * n_total)
    n_val = int(splits[1] * n_total)

    train_ids = image_ids[:n_train]
    val_ids = image_ids[n_train:n_train + n_val]
    test_ids = image_ids[n_train + n_val:]

    def save_subset(ids, save_dir, save_json):
        os.makedirs(save_dir, exist_ok=True)
        
        images = [coco.loadImgs(i)[0] for i in ids]
        anns = sum([coco.loadAnns(coco.getAnnIds(imgIds=i)) for i in ids], [])
        
        subset = {
            "info": ann_data.get("info", {}),
            "licenses": ann_data.get("licenses", []),
            "images": images,
            "annotations": anns,
            "categories": coco.loadCats(coco.getCatIds()),
        }

        with open(save_json, "w") as f:
            json.dump(subset, f, indent=2)

        for img in images:
            src = os.path.join(dataset_dir, "images", img["file_name"])
            dst = os.path.join(save_dir, img["file_name"])
            shutil.copy(src, dst)

    # Save splits
    save_subset(train_ids, os.path.join(dataset_dir, output_dirs[0]), 
                os.path.join(dataset_dir, f"{output_dirs[0]}/{ann_filename}"))
    save_subset(val_ids, os.path.join(dataset_dir, output_dirs[1]), 
                os.path.join(dataset_dir, f"{output_dirs[1]}/{ann_filename}"))
    save_subset(test_ids, os.path.join(dataset_dir, output_dirs[2]), 
                os.path.join(dataset_dir, f"{output_dirs[2]}/{ann_filename}"))

    print(f"Dataset split complete: {len(train_ids)} train, {len(val_ids)} val, {len(test_ids)} test images.")

# %% [markdown]
# ## Process Ambulance Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\ambulance\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 8 unique classes
# Class distribution:
#   Class 0: 32 instances
#   Class 1: 64 instances
#   Class 2: 149 instances
#   Class 3: 1 instances
#   Class 4: 56 instances
#   Class 5: 338 instances
#   Class 6: 8 instances
#   Class 7: 133 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\ambulance", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\ambulance\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\ambulance",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)

# %% [markdown]
# ##  Process Auto Rickshaw Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\auto_rickshaw\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 8 unique classes
# Class distribution:
#   Class 0: 467 instances
#   Class 1: 39 instances
#   Class 2: 32 instances
#   Class 3: 1 instances
#   Class 4: 10 instances
#   Class 5: 2 instances
#   Class 6: 4 instances
#   Class 7: 148 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\auto_rickshaw", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\auto_rickshaw\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\auto_rickshaw",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 208 train, 59 val, 31 test images.

# %% [markdown]
# ## Process Bikes Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\bikes\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 1 unique classes
# Class distribution:
#   Class 7: 447 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\bikes", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\bikes\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\bikes",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 216 train, 61 val, 32 test images.

# %% [markdown]
# ## Process Bus Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\bus\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 8 unique classes
# Class distribution:
#   Class 0: 6 instances
#   Class 1: 505 instances
#   Class 2: 66 instances
#   Class 3: 2 instances
#   Class 4: 22 instances
#   Class 5: 1 instances
#   Class 6: 8 instances
#   Class 7: 36 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\bus", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\bus\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\bus",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 30 test images.

# %% [markdown]
# ## Process Car Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\car\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 7 unique classes
# Class distribution:
#   Class 0: 18 instances
#   Class 1: 27 instances
#   Class 2: 399 instances
#   Class 3: 1 instances
#   Class 4: 13 instances
#   Class 6: 9 instances
#   Class 7: 164 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\car", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\car\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\car",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 213 train, 61 val, 31 test images.

# %% [markdown]
# ## Process E-Rickshaw Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\e-rickshaw\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 7 unique classes
# Class distribution:
#   Class 0: 482 instances
#   Class 1: 14 instances
#   Class 2: 21 instances
#   Class 3: 1 instances
#   Class 4: 4 instances
#   Class 5: 1 instances
#   Class 7: 95 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\e-rickshaw", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\e-rickshaw\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\e-rickshaw",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 30 test images.

# %% [markdown]
# ## Process Mirco-bus Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\micro_bus\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 10 instances
#   Class 1: 358 instances
#   Class 2: 87 instances
#   Class 4: 14 instances
#   Class 6: 2 instances
#   Class 7: 161 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\micro_bus", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\micro_bus\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\micro_bus",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 31 test images.

# %% [markdown]
# ## Process Mini Truck Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\mini_truck\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 9 instances
#   Class 1: 57 instances
#   Class 2: 116 instances
#   Class 4: 348 instances
#   Class 6: 14 instances
#   Class 7: 256 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\mini_truck", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\mini_truck\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\mini_truck",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 212 train, 60 val, 31 test images.

# %% [markdown]
# ## Process Police Vehicle Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\police_vehicle\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 5 unique classes
# Class distribution:
#   Class 1: 2 instances
#   Class 2: 67 instances
#   Class 4: 1 instances
#   Class 6: 1 instances
#   Class 7: 8 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\police_vehicle", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\police_vehicle\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\police_vehicle",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 44 train, 12 val, 7 test images.

# %% [markdown]
# ## Process School Bus Vehicle Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\school_bus\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 20 instances
#   Class 1: 330 instances
#   Class 2: 69 instances
#   Class 4: 19 instances
#   Class 6: 5 instances
#   Class 7: 168 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\school_bus", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\school_bus\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\school_bus",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 30 test images.

# %% [markdown]
# ## Process Scooter Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\scooter\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 8 unique classes
# Class distribution:
#   Class 0: 20 instances
#   Class 1: 8 instances
#   Class 2: 24 instances
#   Class 3: 2 instances
#   Class 4: 7 instances
#   Class 5: 1 instances
#   Class 6: 4 instances
#   Class 7: 438 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\scooter", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\scooter\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\scooter",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 214 train, 61 val, 31 test images.

# %% [markdown]
# ## Process SUV Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\SUV\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 9 instances
#   Class 1: 25 instances
#   Class 2: 409 instances
#   Class 4: 9 instances
#   Class 6: 4 instances
#   Class 7: 96 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\SUV", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\SUV\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\SUV",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 224 train, 64 val, 33 test images.

# %% [markdown]
# ## Process Taxi Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\taxi\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 6 instances
#   Class 1: 40 instances
#   Class 2: 449 instances
#   Class 4: 9 instances
#   Class 6: 7 instances
#   Class 7: 268 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\taxi", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\taxi\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\taxi",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 30 test images.

# %% [markdown]
# ## Process Tempo Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\tempo\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 355 instances
#   Class 1: 48 instances
#   Class 2: 133 instances
#   Class 4: 6 instances
#   Class 6: 13 instances
#   Class 7: 229 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\tempo", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\tempo\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\tempo",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 30 test images.

# %% [markdown]
# ## Process Tractor Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\tractor\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 16 instances
#   Class 1: 1 instances
#   Class 2: 7 instances
#   Class 3: 82 instances
#   Class 4: 7 instances
#   Class 7: 52 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\tractor", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\tractor\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\tractor",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 55 train, 15 val, 9 test images.

# %% [markdown]
# ## Process Transport Vehicle Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\transport_vehicle\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 15 instances
#   Class 1: 59 instances
#   Class 2: 113 instances
#   Class 4: 359 instances
#   Class 6: 8 instances
#   Class 7: 235 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\transport_vehicle", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\transport_vehicle\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\transport_vehicle",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 219 train, 62 val, 32 test images.

# %% [markdown]
# ## Process Truck Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\truck\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 8 unique classes
# Class distribution:
#   Class 0: 10 instances
#   Class 1: 27 instances
#   Class 2: 56 instances
#   Class 3: 2 instances
#   Class 4: 237 instances
#   Class 5: 1 instances
#   Class 6: 6 instances
#   Class 7: 115 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\truck", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\truck\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\truck",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 129 train, 37 val, 19 test images.

# %% [markdown]
# ## Process Van Data

# %%
# investigate number of unique classes in dataset
labels_dir = r"data\Nepali_vehicle_dataset_reduced\van\labels"   # Windows style path


class_counter = count_yolo_classes(labels_dir)

print(f"Found {len(class_counter)} unique classes")
print("Class distribution:")
for cls, count in sorted(class_counter.items()):
    print(f"  Class {cls}: {count} instances")
# Out:
# Found 6 unique classes
# Class distribution:
#   Class 0: 12 instances
#   Class 1: 36 instances
#   Class 2: 68 instances
#   Class 4: 8 instances
#   Class 6: 319 instances
#   Class 7: 117 instances

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\van", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\van\_annotations.coco.json

# %%
# create COCO annotations json file
category_names = [
    "three_wheels",
    "bus",
    "car",
    "tractor",
    "truck",
    "ambulance",
    "van",
    "motorbikes"
]

convert_yolo_to_coco(r"data\Nepali_vehicle_dataset_reduced\van", category_names)
# Out:
# YOLO → COCO conversion complete! Saved to data\Nepali_vehicle_dataset_reduced\van\_annotations.coco.json

# %%
# split dataset into train, valid, and test (70/20/10)
split_coco_dataset(
    dataset_dir=r"data\Nepali_vehicle_dataset_reduced\van",
    ann_filename="_annotations.coco.json",
    splits=(0.7, 0.2, 0.1),
    output_dirs=("train", "valid", "test")
)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Dataset split complete: 210 train, 60 val, 30 test images.
